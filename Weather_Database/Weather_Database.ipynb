# %%
#import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from datetime import datetime

# %%
#3 Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#4 Get the nearest city using the citipy module.
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 734

# %%
#5 Perform an API call with the OpenWeatherMap.
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#6Retrieve the following information from the API call:

city_data = []
print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1

    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]

        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description
                          })

    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ventspils
# Processing Record 2 of Set 1 | hasaki
# Processing Record 3 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 4 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 1 | tuktoyaktuk
# Processing Record 6 of Set 1 | kuang
# Processing Record 7 of Set 1 | takoradi
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | beringovskiy
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | evensk
# Processing Record 12 of Set 1 | port alfred
# Processing Record 13 of Set 1 | bardiyah
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | jumla
# Processing Record 16 of Set 1 | mgandu
# Processing Record 17 of Set 1 | kotelnich
# Processing Record 18 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 1 | kaitangata
# Processing Record 20 of Set 1 | vaini
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | port elizabeth
# Processing Record 23 of Set 1 | avarua
# Processing Record 24 of Set 1 | port shepstone
# Processing Record 25 of Set 1 | halifax
# Processing Record 26 of Set 1 | bluff
# Processing Record 27 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 1 | henties bay
# Processing Record 29 of Set 1 | saint-augustin
# Processing Record 30 of Set 1 | olafsvik
# Processing Record 31 of Set 1 | puerto ayora
# Processing Record 32 of Set 1 | arica
# Processing Record 33 of Set 1 | atuona
# Processing Record 34 of Set 1 | hithadhoo
# Processing Record 35 of Set 1 | jamestown
# Processing Record 36 of Set 1 | katangli
# Processing Record 37 of Set 1 | esperance
# Processing Record 38 of Set 1 | namatanai
# Processing Record 39 of Set 1 | lephepe
# City not found. Skipping...
# Processing Record 40 of Set 1 | ancud
# Processing Record 41 of Set 1 | meulaboh
# Processing Record 42 of Set 1 | ahipara
# Processing Record 43 of Set 1 | kangaatsiaq
# Processing Record 44 of Set 1 | nikolskoye
# Processing Record 45 of Set 1 | kailua
# Processing Record 46 of Set 1 | khatanga
# Processing Record 47 of Set 1 | kirensk
# Processing Record 48 of Set 1 | tashtyp
# Processing Record 49 of Set 1 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 50 of Set 1 | beisfjord
# Processing Record 1 of Set 2 | grindavik
# Processing Record 2 of Set 2 | kota bahru
# Processing Record 3 of Set 2 | saint george
# Processing Record 4 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 2 | sur
# Processing Record 6 of Set 2 | pevek
# Processing Record 7 of Set 2 | tsentralnyy
# City not found. Skipping...
# Processing Record 8 of Set 2 | punta arenas
# Processing Record 9 of Set 2 | busselton
# Processing Record 10 of Set 2 | iqaluit
# Processing Record 11 of Set 2 | mangan
# Processing Record 12 of Set 2 | saskylakh
# Processing Record 13 of Set 2 | kudahuvadhoo
# Processing Record 14 of Set 2 | bandarbeyla
# Processing Record 15 of Set 2 | pisco
# Processing Record 16 of Set 2 | cambrils
# Processing Record 17 of Set 2 | qasigiannguit
# Processing Record 18 of Set 2 | jimma
# Processing Record 19 of Set 2 | eureka
# Processing Record 20 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 2 | ormara
# Processing Record 22 of Set 2 | vestmannaeyjar
# Processing Record 23 of Set 2 | taoudenni
# Processing Record 24 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 25 of Set 2 | chuy
# Processing Record 26 of Set 2 | souillac
# Processing Record 27 of Set 2 | yar-sale
# Processing Record 28 of Set 2 | dhidhdhoo
# Processing Record 29 of Set 2 | barrow
# Processing Record 30 of Set 2 | sirajganj
# Processing Record 31 of Set 2 | bethel
# Processing Record 32 of Set 2 | qaanaaq
# Processing Record 33 of Set 2 | batemans bay
# Processing Record 34 of Set 2 | rikitea
# Processing Record 35 of Set 2 | hilo
# Processing Record 36 of Set 2 | dikson
# Processing Record 37 of Set 2 | tanjong karang
# City not found. Skipping...
# Processing Record 38 of Set 2 | fairbanks
# Processing Record 39 of Set 2 | provideniya
# Processing Record 40 of Set 2 | kununurra
# Processing Record 41 of Set 2 | gat
# Processing Record 42 of Set 2 | tiarei
# Processing Record 43 of Set 2 | ugoofaaru
# Processing Record 44 of Set 2 | cape town
# Processing Record 45 of Set 2 | carnarvon
# Processing Record 46 of Set 2 | hermanus
# Processing Record 47 of Set 2 | fortuna
# Processing Record 48 of Set 2 | severo-kurilsk
# Processing Record 49 of Set 2 | san felipe
# Processing Record 50 of Set 2 | tuatapere
# Processing Record 1 of Set 3 | nador
# Processing Record 2 of Set 3 | yerbogachen
# Processing Record 3 of Set 3 | san quintin
# Processing Record 4 of Set 3 | blind river
# Processing Record 5 of Set 3 | mercedes
# Processing Record 6 of Set 3 | cabo san lucas
# Processing Record 7 of Set 3 | butaritari
# Processing Record 8 of Set 3 | xai-xai
# Processing Record 9 of Set 3 | mosquera
# Processing Record 10 of Set 3 | hobart
# Processing Record 11 of Set 3 | komsomolskiy
# Processing Record 12 of Set 3 | aklavik
# Processing Record 13 of Set 3 | camacha
# Processing Record 14 of Set 3 | praia
# Processing Record 15 of Set 3 | buraydah
# Processing Record 16 of Set 3 | sorland
# Processing Record 17 of Set 3 | lebu
# Processing Record 18 of Set 3 | bonnyville
# Processing Record 19 of Set 3 | riviere-au-renard
# Processing Record 20 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 21 of Set 3 | isangel
# Processing Record 22 of Set 3 | pokosnoye
# Processing Record 23 of Set 3 | leningradskiy
# Processing Record 24 of Set 3 | asosa
# Processing Record 25 of Set 3 | glendive
# Processing Record 26 of Set 3 | kijang
# Processing Record 27 of Set 3 | bengkulu
# Processing Record 28 of Set 3 | castro
# Processing Record 29 of Set 3 | tabarqah
# City not found. Skipping...
# Processing Record 30 of Set 3 | bredasdorp
# Processing Record 31 of Set 3 | belmonte
# Processing Record 32 of Set 3 | oranjemund
# Processing Record 33 of Set 3 | yarmouth
# Processing Record 34 of Set 3 | tazovskiy
# Processing Record 35 of Set 3 | ayagoz
# Processing Record 36 of Set 3 | husavik
# Processing Record 37 of Set 3 | bathsheba
# Processing Record 38 of Set 3 | fort nelson
# Processing Record 39 of Set 3 | vila franca do campo
# Processing Record 40 of Set 3 | usinsk
# Processing Record 41 of Set 3 | srednekolymsk
# Processing Record 42 of Set 3 | la ronge
# Processing Record 43 of Set 3 | alice springs
# Processing Record 44 of Set 3 | upernavik
# Processing Record 45 of Set 3 | port-gentil
# Processing Record 46 of Set 3 | nettuno
# Processing Record 47 of Set 3 | lovozero
# Processing Record 48 of Set 3 | airai
# Processing Record 49 of Set 3 | cap malheureux
# Processing Record 50 of Set 3 | dawlatabad
# Processing Record 1 of Set 4 | berlevag
# Processing Record 2 of Set 4 | kapaa
# Processing Record 3 of Set 4 | muros
# Processing Record 4 of Set 4 | terrak
# Processing Record 5 of Set 4 | arraial do cabo
# Processing Record 6 of Set 4 | cidreira
# Processing Record 7 of Set 4 | new norfolk
# Processing Record 8 of Set 4 | cherskiy
# Processing Record 9 of Set 4 | honiara
# Processing Record 10 of Set 4 | pangnirtung
# Processing Record 11 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 4 | bonavista
# Processing Record 13 of Set 4 | east london
# Processing Record 14 of Set 4 | winchester
# Processing Record 15 of Set 4 | nioro
# Processing Record 16 of Set 4 | ningyang
# Processing Record 17 of Set 4 | te anau
# Processing Record 18 of Set 4 | deputatskiy
# Processing Record 19 of Set 4 | abonnema
# Processing Record 20 of Set 4 | mahebourg
# Processing Record 21 of Set 4 | kavieng
# Processing Record 22 of Set 4 | huilong
# Processing Record 23 of Set 4 | atka
# City not found. Skipping...
# Processing Record 24 of Set 4 | bundaberg
# Processing Record 25 of Set 4 | hualmay
# Processing Record 26 of Set 4 | kirya
# Processing Record 27 of Set 4 | akureyri
# Processing Record 28 of Set 4 | nanortalik
# Processing Record 29 of Set 4 | kaeo
# Processing Record 30 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 4 | monterotondo
# Processing Record 32 of Set 4 | razole
# Processing Record 33 of Set 4 | rawson
# Processing Record 34 of Set 4 | aras
# Processing Record 35 of Set 4 | marienburg
# Processing Record 36 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 4 | salta
# Processing Record 38 of Set 4 | bykovo
# Processing Record 39 of Set 4 | bichena
# Processing Record 40 of Set 4 | ouallam
# Processing Record 41 of Set 4 | mattawa
# Processing Record 42 of Set 4 | japura
# Processing Record 43 of Set 4 | coihaique
# Processing Record 44 of Set 4 | vardo
# Processing Record 45 of Set 4 | manthani
# Processing Record 46 of Set 4 | hamilton
# Processing Record 47 of Set 4 | severo-yeniseyskiy
# Processing Record 48 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 4 | kruisfontein
# Processing Record 50 of Set 4 | victoria
# Processing Record 1 of Set 5 | orlik
# Processing Record 2 of Set 5 | haines junction
# Processing Record 3 of Set 5 | atar
# Processing Record 4 of Set 5 | puteyets
# Processing Record 5 of Set 5 | narsaq
# Processing Record 6 of Set 5 | trapani
# Processing Record 7 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 8 of Set 5 | moranbah
# Processing Record 9 of Set 5 | prince albert
# Processing Record 10 of Set 5 | okhotsk
# Processing Record 11 of Set 5 | santarem
# Processing Record 12 of Set 5 | kidal
# Processing Record 13 of Set 5 | kahului
# Processing Record 14 of Set 5 | tual
# Processing Record 15 of Set 5 | soyo
# Processing Record 16 of Set 5 | tomatlan
# Processing Record 17 of Set 5 | swan hill
# Processing Record 18 of Set 5 | savinka
# Processing Record 19 of Set 5 | santa fe
# Processing Record 20 of Set 5 | mar del plata
# Processing Record 21 of Set 5 | port blair
# Processing Record 22 of Set 5 | durant
# Processing Record 23 of Set 5 | udachnyy
# Processing Record 24 of Set 5 | bairiki
# Processing Record 25 of Set 5 | peking
# Processing Record 26 of Set 5 | portland
# Processing Record 27 of Set 5 | nome
# Processing Record 28 of Set 5 | saint-philippe
# Processing Record 29 of Set 5 | cascais
# Processing Record 30 of Set 5 | norman wells
# Processing Record 31 of Set 5 | mapiri
# Processing Record 32 of Set 5 | dalvik
# Processing Record 33 of Set 5 | shenzhen
# Processing Record 34 of Set 5 | tombouctou
# Processing Record 35 of Set 5 | longyearbyen
# Processing Record 36 of Set 5 | senigallia
# Processing Record 37 of Set 5 | sao filipe
# Processing Record 38 of Set 5 | carauari
# Processing Record 39 of Set 5 | bata
# Processing Record 40 of Set 5 | sorgun
# Processing Record 41 of Set 5 | altay
# Processing Record 42 of Set 5 | tahe
# Processing Record 43 of Set 5 | gheorgheni
# Processing Record 44 of Set 5 | lagoa
# Processing Record 45 of Set 5 | cockburn town
# Processing Record 46 of Set 5 | riaba
# City not found. Skipping...
# Processing Record 47 of Set 5 | sirawai
# Processing Record 48 of Set 5 | thompson
# Processing Record 49 of Set 5 | cervo
# Processing Record 50 of Set 5 | mathbaria
# Processing Record 1 of Set 6 | vanavara
# Processing Record 2 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 3 of Set 6 | kavaratti
# Processing Record 4 of Set 6 | chunoyar
# Processing Record 5 of Set 6 | newport
# Processing Record 6 of Set 6 | uusikaupunki
# Processing Record 7 of Set 6 | geraldton
# Processing Record 8 of Set 6 | buzmeyin
# Processing Record 9 of Set 6 | ewa beach
# Processing Record 10 of Set 6 | serebryansk
# Processing Record 11 of Set 6 | poya
# Processing Record 12 of Set 6 | lompoc
# Processing Record 13 of Set 6 | padang
# Processing Record 14 of Set 6 | gulshat
# City not found. Skipping...
# Processing Record 15 of Set 6 | vidalia
# Processing Record 16 of Set 6 | chapais
# Processing Record 17 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 6 | probistip
# Processing Record 19 of Set 6 | estacion coahuila
# Processing Record 20 of Set 6 | tocopilla
# Processing Record 21 of Set 6 | jawhar
# Processing Record 22 of Set 6 | kaseda
# Processing Record 23 of Set 6 | chokurdakh
# Processing Record 24 of Set 6 | verkhnevilyuysk
# Processing Record 25 of Set 6 | abu kamal
# Processing Record 26 of Set 6 | nishihara
# Processing Record 27 of Set 6 | mpanda
# Processing Record 28 of Set 6 | maunabo
# Processing Record 29 of Set 6 | zhezkazgan
# Processing Record 30 of Set 6 | kodiak
# Processing Record 31 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 6 | umm durman
# City not found. Skipping...
# Processing Record 33 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 6 | arlit
# Processing Record 36 of Set 6 | torrington
# Processing Record 37 of Set 6 | salalah
# Processing Record 38 of Set 6 | antofagasta
# Processing Record 39 of Set 6 | mayo
# Processing Record 40 of Set 6 | joensuu
# Processing Record 41 of Set 6 | codrington
# Processing Record 42 of Set 6 | ternate
# Processing Record 43 of Set 6 | manaure
# Processing Record 44 of Set 6 | bambous virieux
# Processing Record 45 of Set 6 | ixtapa
# Processing Record 46 of Set 6 | saldanha
# Processing Record 47 of Set 6 | saint anthony
# Processing Record 48 of Set 6 | lorengau
# Processing Record 49 of Set 6 | hailey
# Processing Record 50 of Set 6 | nalut
# Processing Record 1 of Set 7 | nemuro
# Processing Record 2 of Set 7 | wattegama
# Processing Record 3 of Set 7 | san patricio
# Processing Record 4 of Set 7 | seminole
# Processing Record 5 of Set 7 | harper
# Processing Record 6 of Set 7 | torbay
# Processing Record 7 of Set 7 | tlanalapan
# Processing Record 8 of Set 7 | isla mujeres
# Processing Record 9 of Set 7 | acarau
# Processing Record 10 of Set 7 | sydney
# Processing Record 11 of Set 7 | kalmunai
# Processing Record 12 of Set 7 | mansar
# Processing Record 13 of Set 7 | concordia
# Processing Record 14 of Set 7 | myrtle beach
# Processing Record 15 of Set 7 | prince rupert
# Processing Record 16 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 7 | rio gallegos
# Processing Record 18 of Set 7 | northam
# Processing Record 19 of Set 7 | mwanza
# Processing Record 20 of Set 7 | paka
# Processing Record 21 of Set 7 | markova
# Processing Record 22 of Set 7 | demmin
# Processing Record 23 of Set 7 | anda
# Processing Record 24 of Set 7 | pimenta bueno
# Processing Record 25 of Set 7 | anadyr
# Processing Record 26 of Set 7 | umea
# Processing Record 27 of Set 7 | grand gaube
# Processing Record 28 of Set 7 | linqing
# Processing Record 29 of Set 7 | ponta do sol
# Processing Record 30 of Set 7 | tamworth
# Processing Record 31 of Set 7 | tiksi
# Processing Record 32 of Set 7 | turukhansk
# Processing Record 33 of Set 7 | granard
# Processing Record 34 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 7 | mindelo
# Processing Record 36 of Set 7 | tucumcari
# Processing Record 37 of Set 7 | port keats
# Processing Record 38 of Set 7 | babanusah
# City not found. Skipping...
# Processing Record 39 of Set 7 | litovko
# Processing Record 40 of Set 7 | carthage
# Processing Record 41 of Set 7 | praia da vitoria
# Processing Record 42 of Set 7 | vilhena
# Processing Record 43 of Set 7 | kuytun
# Processing Record 44 of Set 7 | ahuimanu
# Processing Record 45 of Set 7 | avera
# Processing Record 46 of Set 7 | sobolevo
# Processing Record 47 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 48 of Set 7 | saint-vallier
# Processing Record 49 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 7 | georgetown
# Processing Record 1 of Set 8 | sioux lookout
# Processing Record 2 of Set 8 | mount isa
# Processing Record 3 of Set 8 | atherton
# Processing Record 4 of Set 8 | winslow
# Processing Record 5 of Set 8 | susangerd
# Processing Record 6 of Set 8 | mao
# Processing Record 7 of Set 8 | bilibino
# Processing Record 8 of Set 8 | eyl
# Processing Record 9 of Set 8 | kirksville
# Processing Record 10 of Set 8 | tautira
# Processing Record 11 of Set 8 | selaphum
# Processing Record 12 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 13 of Set 8 | karamea
# City not found. Skipping...
# Processing Record 14 of Set 8 | ilulissat
# Processing Record 15 of Set 8 | baykit
# Processing Record 16 of Set 8 | petrivka
# Processing Record 17 of Set 8 | biak
# Processing Record 18 of Set 8 | kuala terengganu
# Processing Record 19 of Set 8 | touros
# Processing Record 20 of Set 8 | luderitz
# Processing Record 21 of Set 8 | barra do garcas
# Processing Record 22 of Set 8 | dingle
# Processing Record 23 of Set 8 | chopovychi
# Processing Record 24 of Set 8 | great yarmouth
# Processing Record 25 of Set 8 | horni plana
# Processing Record 26 of Set 8 | ostrovnoy
# Processing Record 27 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 28 of Set 8 | atyashevo
# Processing Record 29 of Set 8 | mackenzie
# Processing Record 30 of Set 8 | tasiilaq
# Processing Record 31 of Set 8 | himora
# City not found. Skipping...
# Processing Record 32 of Set 8 | asau
# Processing Record 33 of Set 8 | liverpool
# Processing Record 34 of Set 8 | beaupre
# Processing Record 35 of Set 8 | sept-iles
# Processing Record 36 of Set 8 | robertsport
# Processing Record 37 of Set 8 | iquique
# Processing Record 38 of Set 8 | bubaque
# Processing Record 39 of Set 8 | kihei
# Processing Record 40 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 41 of Set 8 | maine-soroa
# Processing Record 42 of Set 8 | katsuura
# Processing Record 43 of Set 8 | sibolga
# Processing Record 44 of Set 8 | seymchan
# Processing Record 45 of Set 8 | tchollire
# Processing Record 46 of Set 8 | santa rosa
# Processing Record 47 of Set 8 | qaqortoq
# Processing Record 48 of Set 8 | macheng
# Processing Record 49 of Set 8 | tamiahua
# Processing Record 50 of Set 8 | ostersund
# Processing Record 1 of Set 9 | sivas
# Processing Record 2 of Set 9 | talnakh
# Processing Record 3 of Set 9 | agva
# City not found. Skipping...
# Processing Record 4 of Set 9 | vryburg
# Processing Record 5 of Set 9 | lac du bonnet
# Processing Record 6 of Set 9 | westport
# Processing Record 7 of Set 9 | karratha
# Processing Record 8 of Set 9 | sorong
# Processing Record 9 of Set 9 | raffadali
# Processing Record 10 of Set 9 | karachi
# Processing Record 11 of Set 9 | cayenne
# Processing Record 12 of Set 9 | galle
# Processing Record 13 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 14 of Set 9 | ornskoldsvik
# Processing Record 15 of Set 9 | bubanza
# Processing Record 16 of Set 9 | limon
# Processing Record 17 of Set 9 | adrar
# Processing Record 18 of Set 9 | awbari
# Processing Record 19 of Set 9 | male
# Processing Record 20 of Set 9 | muriwai beach
# Processing Record 21 of Set 9 | key west
# Processing Record 22 of Set 9 | vostok
# Processing Record 23 of Set 9 | meiganga
# Processing Record 24 of Set 9 | taltal
# Processing Record 25 of Set 9 | aybak
# City not found. Skipping...
# Processing Record 26 of Set 9 | termoli
# Processing Record 27 of Set 9 | la rioja
# Processing Record 28 of Set 9 | ust-tsilma
# Processing Record 29 of Set 9 | rocha
# Processing Record 30 of Set 9 | wagrowiec
# Processing Record 31 of Set 9 | sao jose da coroa grande
# Processing Record 32 of Set 9 | ilhabela
# Processing Record 33 of Set 9 | barela
# Processing Record 34 of Set 9 | jiuquan
# Processing Record 35 of Set 9 | kollumerland
# City not found. Skipping...
# Processing Record 36 of Set 9 | kaili
# Processing Record 37 of Set 9 | conceicao do araguaia
# Processing Record 38 of Set 9 | banda aceh
# Processing Record 39 of Set 9 | port lincoln
# Processing Record 40 of Set 9 | boffa
# Processing Record 41 of Set 9 | sampit
# Processing Record 42 of Set 9 | tiznit
# Processing Record 43 of Set 9 | oktyabrskoye
# Processing Record 44 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 45 of Set 9 | goundam
# Processing Record 46 of Set 9 | angoram
# Processing Record 47 of Set 9 | puerto escondido
# Processing Record 48 of Set 9 | comodoro rivadavia
# Processing Record 49 of Set 9 | vila velha
# Processing Record 50 of Set 9 | ribeira grande
# Processing Record 1 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 10 | marsassoum
# Processing Record 3 of Set 10 | marawi
# Processing Record 4 of Set 10 | hovd
# Processing Record 5 of Set 10 | pizarro
# Processing Record 6 of Set 10 | gweta
# Processing Record 7 of Set 10 | mehamn
# Processing Record 8 of Set 10 | crixas
# Processing Record 9 of Set 10 | mantua
# Processing Record 10 of Set 10 | hudson bay
# Processing Record 11 of Set 10 | kamen-rybolov
# Processing Record 12 of Set 10 | chabahar
# Processing Record 13 of Set 10 | nouadhibou
# Processing Record 14 of Set 10 | uyemskiy
# Processing Record 15 of Set 10 | khagrachari
# City not found. Skipping...
# Processing Record 16 of Set 10 | ortona
# Processing Record 17 of Set 10 | nyurba
# Processing Record 18 of Set 10 | antunez
# Processing Record 19 of Set 10 | garowe
# Processing Record 20 of Set 10 | kaoma
# Processing Record 21 of Set 10 | mogadishu
# Processing Record 22 of Set 10 | tuban
# Processing Record 23 of Set 10 | batagay-alyta
# Processing Record 24 of Set 10 | aguimes
# Processing Record 25 of Set 10 | road town
# Processing Record 26 of Set 10 | natal
# Processing Record 27 of Set 10 | constitucion
# Processing Record 28 of Set 10 | hirara
# Processing Record 29 of Set 10 | witu
# Processing Record 30 of Set 10 | basco
# Processing Record 31 of Set 10 | tromso
# Processing Record 32 of Set 10 | samarkand
# Processing Record 33 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 10 | charters towers
# Processing Record 35 of Set 10 | plettenberg bay
# Processing Record 36 of Set 10 | faanui
# Processing Record 37 of Set 10 | ilkal
# Processing Record 38 of Set 10 | sitka
# Processing Record 39 of Set 10 | nadvoitsy
# Processing Record 40 of Set 10 | lima
# Processing Record 41 of Set 10 | hofn
# Processing Record 42 of Set 10 | puerto leguizamo
# Processing Record 43 of Set 10 | poum
# Processing Record 44 of Set 10 | radyvyliv
# Processing Record 45 of Set 10 | krasnoselkup
# Processing Record 46 of Set 10 | machico
# Processing Record 47 of Set 10 | shelburne
# Processing Record 48 of Set 10 | bokspits
# City not found. Skipping...
# Processing Record 49 of Set 10 | college
# Processing Record 50 of Set 10 | sao joao da barra
# Processing Record 1 of Set 11 | orel-izumrud
# Processing Record 2 of Set 11 | tura
# Processing Record 3 of Set 11 | bowen
# Processing Record 4 of Set 11 | tomigusuku
# Processing Record 5 of Set 11 | esso
# Processing Record 6 of Set 11 | bartica
# Processing Record 7 of Set 11 | vega de alatorre
# Processing Record 8 of Set 11 | urubicha
# Processing Record 9 of Set 11 | chernyshevskiy
# Processing Record 10 of Set 11 | atkinson
# Processing Record 11 of Set 11 | andros town
# Processing Record 12 of Set 11 | ribeirao do pinhal
# City not found. Skipping...
# Processing Record 13 of Set 11 | miyako
# Processing Record 14 of Set 11 | makakilo city
# Processing Record 15 of Set 11 | biloli
# Processing Record 16 of Set 11 | terra santa
# Processing Record 17 of Set 11 | great bend
# Processing Record 18 of Set 11 | kommunisticheskiy
# Processing Record 19 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 20 of Set 11 | wajima
# Processing Record 21 of Set 11 | lamu
# Processing Record 22 of Set 11 | siddipet
# Processing Record 23 of Set 11 | korla
# Processing Record 24 of Set 11 | margate
# Processing Record 25 of Set 11 | chirongui
# Processing Record 26 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 27 of Set 11 | manakara
# Processing Record 28 of Set 11 | the pas
# Processing Record 29 of Set 11 | bandar-e lengeh
# Processing Record 30 of Set 11 | waingapu
# Processing Record 31 of Set 11 | odienne
# Processing Record 32 of Set 11 | ridgecrest
# Processing Record 33 of Set 11 | peniche
# Processing Record 34 of Set 11 | opuwo
# Processing Record 35 of Set 11 | clyde river
# Processing Record 36 of Set 11 | keta
# Processing Record 37 of Set 11 | madras
# Processing Record 38 of Set 11 | tessalit
# Processing Record 39 of Set 11 | maldonado
# Processing Record 40 of Set 11 | nobeoka
# Processing Record 41 of Set 11 | kolokani
# Processing Record 42 of Set 11 | raudeberg
# Processing Record 43 of Set 11 | maun
# Processing Record 44 of Set 11 | khormuj
# City not found. Skipping...
# Processing Record 45 of Set 11 | sola
# Processing Record 46 of Set 11 | havoysund
# Processing Record 47 of Set 11 | andenes
# Processing Record 48 of Set 11 | harsin
# Processing Record 49 of Set 11 | puerto madryn
# Processing Record 50 of Set 11 | punta
# Processing Record 1 of Set 12 | sao miguel do oeste
# City not found. Skipping...
# Processing Record 2 of Set 12 | takob
# City not found. Skipping...
# Processing Record 3 of Set 12 | sinop
# Processing Record 4 of Set 12 | grand forks
# Processing Record 5 of Set 12 | ordzhonikidze
# Processing Record 6 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 7 of Set 12 | catamarca
# Processing Record 8 of Set 12 | kirakira
# Processing Record 9 of Set 12 | shellbrook
# Processing Record 10 of Set 12 | yakeshi
# Processing Record 11 of Set 12 | alofi
# Processing Record 12 of Set 12 | yulin
# Processing Record 13 of Set 12 | makushino
# Processing Record 14 of Set 12 | sainte-marie
# Processing Record 15 of Set 12 | mogok
# Processing Record 16 of Set 12 | cabadiangan
# Processing Record 17 of Set 12 | pangoa
# Processing Record 18 of Set 12 | anapskaya
# Processing Record 19 of Set 12 | forst
# Processing Record 20 of Set 12 | warrnambool
# Processing Record 21 of Set 12 | dvinskoy
# Processing Record 22 of Set 12 | almaznyy
# Processing Record 23 of Set 12 | wiwili
# Processing Record 24 of Set 12 | kamaishi
# Processing Record 25 of Set 12 | santa maria
# Processing Record 26 of Set 12 | kochi
# Processing Record 27 of Set 12 | okha
# Processing Record 28 of Set 12 | taksimo
# Processing Record 29 of Set 12 | sokolow podlaski
# Processing Record 30 of Set 12 | jaffna
# Processing Record 31 of Set 12 | viedma
# Processing Record 32 of Set 12 | port moresby
# Processing Record 33 of Set 12 | burica
# City not found. Skipping...
# Processing Record 34 of Set 12 | mulanje
# Processing Record 35 of Set 12 | paso de carrasco
# Processing Record 36 of Set 12 | lata
# Processing Record 37 of Set 12 | half moon bay
# Processing Record 38 of Set 12 | ust-nera
# Processing Record 39 of Set 12 | nizhniy kuranakh
# Processing Record 40 of Set 12 | otradnoye
# Processing Record 41 of Set 12 | laguna
# Processing Record 42 of Set 12 | teguldet
# Processing Record 43 of Set 12 | hibbing
# Processing Record 44 of Set 12 | roswell
# Processing Record 45 of Set 12 | zhigansk
# Processing Record 46 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 47 of Set 12 | radomsko
# Processing Record 48 of Set 12 | mae hong son
# Processing Record 49 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 50 of Set 12 | russell
# Processing Record 1 of Set 13 | itoman
# Processing Record 2 of Set 13 | ahome
# Processing Record 3 of Set 13 | alzamay
# Processing Record 4 of Set 13 | egvekinot
# Processing Record 5 of Set 13 | lapua
# Processing Record 6 of Set 13 | providencia
# Processing Record 7 of Set 13 | jvari
# Processing Record 8 of Set 13 | hudiksvall
# Processing Record 9 of Set 13 | klaksvik
# Processing Record 10 of Set 13 | sao paulo do potengi
# Processing Record 11 of Set 13 | san pedro
# Processing Record 12 of Set 13 | calvinia
# Processing Record 13 of Set 13 | karaton
# Processing Record 14 of Set 13 | lasa
# Processing Record 15 of Set 13 | coquimbo
# Processing Record 16 of Set 13 | tilichiki
# Processing Record 17 of Set 13 | claresholm
# Processing Record 18 of Set 13 | tulnici
# Processing Record 19 of Set 13 | urumqi
# Processing Record 20 of Set 13 | griffith
# Processing Record 21 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 22 of Set 13 | north platte
# Processing Record 23 of Set 13 | elbistan
# Processing Record 24 of Set 13 | mount gambier
# Processing Record 25 of Set 13 | dongsheng
# Processing Record 26 of Set 13 | doha
# Processing Record 27 of Set 13 | maniitsoq
# Processing Record 28 of Set 13 | north bend
# Processing Record 29 of Set 13 | mudyuga
# City not found. Skipping...
# Processing Record 30 of Set 13 | vilia
# Processing Record 31 of Set 13 | middletown
# Processing Record 32 of Set 13 | san jose
# Processing Record 33 of Set 13 | oussouye
# Processing Record 34 of Set 13 | goderich
# Processing Record 35 of Set 13 | harsud
# Processing Record 36 of Set 13 | radzyn podlaski
# Processing Record 37 of Set 13 | alyangula
# Processing Record 38 of Set 13 | lady frere
# Processing Record 39 of Set 13 | saint-pierre
# Processing Record 40 of Set 13 | genhe
# Processing Record 41 of Set 13 | kirove
# Processing Record 42 of Set 13 | san jeronimo
# Processing Record 43 of Set 13 | shingu
# Processing Record 44 of Set 13 | trojes
# Processing Record 45 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 46 of Set 13 | parabel
# Processing Record 47 of Set 13 | walvis bay
# Processing Record 48 of Set 13 | valle hermoso
# Processing Record 49 of Set 13 | necochea
# Processing Record 50 of Set 13 | ronneby
# Processing Record 1 of Set 14 | alcudia
# Processing Record 2 of Set 14 | porbandar
# Processing Record 3 of Set 14 | petatlan
# Processing Record 4 of Set 14 | leh
# Processing Record 5 of Set 14 | eskisehir
# Processing Record 6 of Set 14 | apt
# Processing Record 7 of Set 14 | kutum
# Processing Record 8 of Set 14 | sopelana
# Processing Record 9 of Set 14 | auki
# Processing Record 10 of Set 14 | vigeland
# Processing Record 11 of Set 14 | lavrentiya
# Processing Record 12 of Set 14 | togur
# Processing Record 13 of Set 14 | pec
# Processing Record 14 of Set 14 | gizo
# Processing Record 15 of Set 14 | lake havasu city
# Processing Record 16 of Set 14 | mongo
# Processing Record 17 of Set 14 | afua
# Processing Record 18 of Set 14 | ossora
# Processing Record 19 of Set 14 | marau
# Processing Record 20 of Set 14 | mitsamiouli
# Processing Record 21 of Set 14 | altamira
# Processing Record 22 of Set 14 | noyabrsk
# Processing Record 23 of Set 14 | flinders
# Processing Record 24 of Set 14 | mansa
# Processing Record 25 of Set 14 | tabas
# Processing Record 26 of Set 14 | grao mogol
# Processing Record 27 of Set 14 | hanmer springs
# Processing Record 28 of Set 14 | samarai
# Processing Record 29 of Set 14 | angoche
# Processing Record 30 of Set 14 | jardim
# Processing Record 31 of Set 14 | dali
# Processing Record 32 of Set 14 | kenai
# Processing Record 33 of Set 14 | yeniseysk
# Processing Record 34 of Set 14 | namibe
# Processing Record 35 of Set 14 | barrhead
# Processing Record 36 of Set 14 | prainha
# Processing Record 37 of Set 14 | yelizovo
# Processing Record 38 of Set 14 | innisfail
# Processing Record 39 of Set 14 | ojinaga
# Processing Record 40 of Set 14 | abaca
# Processing Record 41 of Set 14 | rostovka
# Processing Record 42 of Set 14 | paamiut
# Processing Record 43 of Set 14 | cochabamba
# Processing Record 44 of Set 14 | ambon
# Processing Record 45 of Set 14 | la sarre
# Processing Record 46 of Set 14 | solnechnyy
# Processing Record 47 of Set 14 | hailin
# Processing Record 48 of Set 14 | guerrero negro
# Processing Record 49 of Set 14 | ankang
# Processing Record 50 of Set 14 | bilma
# Processing Record 1 of Set 15 | arman
# Processing Record 2 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 15 | itupiranga
# Processing Record 4 of Set 15 | fukue
# Processing Record 5 of Set 15 | marsa matruh
# Processing Record 6 of Set 15 | eravur
# Processing Record 7 of Set 15 | bajna
# Processing Record 8 of Set 15 | kandrian
# Processing Record 9 of Set 15 | mbini
# Processing Record 10 of Set 15 | kismayo
# Processing Record 11 of Set 15 | aksarka
# Processing Record 12 of Set 15 | bima
# Processing Record 13 of Set 15 | dafeng
# Processing Record 14 of Set 15 | ryotsu
# Processing Record 15 of Set 15 | aripuana
# Processing Record 16 of Set 15 | novyy urengoy
# Processing Record 17 of Set 15 | ust-donetskiy
# Processing Record 18 of Set 15 | nizhniy odes
# Processing Record 19 of Set 15 | rio grande
# Processing Record 20 of Set 15 | pingdingshan
# Processing Record 21 of Set 15 | phan thiet
# Processing Record 22 of Set 15 | nanning
# Processing Record 23 of Set 15 | kaukauna
# Processing Record 24 of Set 15 | bara
# Processing Record 25 of Set 15 | trelew
# Processing Record 26 of Set 15 | derzhavinsk
# Processing Record 27 of Set 15 | kieta
# Processing Record 28 of Set 15 | roald
# Processing Record 29 of Set 15 | makokou
# Processing Record 30 of Set 15 | kampene
# Processing Record 31 of Set 15 | kurkino
# Processing Record 32 of Set 15 | vigia del fuerte
# Processing Record 33 of Set 15 | crab hill
# City not found. Skipping...
# Processing Record 34 of Set 15 | flin flon
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 674

# %%
#7 Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Ventspils      LV  57.3894   21.5606     35.60        93          90
# 1        Hasaki      JP  35.7333  140.8333     64.00        63          75
# 2   Tuktoyaktuk      CA  69.4541 -133.0374     26.60        80          20
# 3         Kuang      MY   3.2594  101.5541     80.01        89          20
# 4      Takoradi      GH   4.8845   -1.7554     80.76        85          78
# 5       Ushuaia      AR -54.8000  -68.3000     50.00        50          40
# 6  Beringovskiy      RU  63.0500  179.3167     32.22        93         100
# 7       Mataura      NZ -46.1927  168.8643     48.99        78          93
# 8        Evensk      RU  61.9500  159.2333     26.92        74         100
# 9   Port Alfred      ZA -33.5906   26.8910     65.19        83          67
#
#    Wind Speed Current Description
# 0       17.27     overcast clouds
# 1       10.36       broken clouds
# 2        6.91          few clouds
# 3        1.50          few clouds
# 4        7.96          light rain
# 5        1.14    scattered clouds
# 6        4.16     overcast clouds
# 7        7.00     overcast clouds
# 8       11.77     overcast clouds
# 9        7.74       broken clouds

# %%
#8. Export Data to CSV
output_data_file = "WeatherPy_database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
